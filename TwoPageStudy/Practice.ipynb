# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl

# %matplotlib inline

mpl.rcParams['axes.unicode_minus'] = False

# %%
df = pd.DataFrame(np.random.rand(10, 4), columns=['a', 'b', 'c', 'd'])

# %%
df
# Out:
#           a         b         c         d
# 0  0.420627  0.522679  0.872259  0.909582
# 1  0.000424  0.902003  0.847213  0.024962
# 2  0.228026  0.087360  0.389755  0.045898
# 3  0.186401  0.356668  0.993218  0.211567
# 4  0.500621  0.073627  0.113171  0.019972
# 5  0.088453  0.184944  0.535080  0.299465
# 6  0.404703  0.643159  0.707527  0.442080
# 7  0.781723  0.539254  0.342665  0.920252
# 8  0.216538  0.904827  0.514334  0.023773
# 9  0.744587  0.403318  0.368613  0.567084

# %%
df.plot.area(stacked=False, grid=True)
# Out:
# <AxesSubplot:>

# %%
df.plot.area(stacked=True, grid=True)
# Out:
# <AxesSubplot:>

# %%
df.plot(grid=True)
# Out:
# <AxesSubplot:>

# %%
df = pd.DataFrame(np.random.rand(1000, 2), columns=['a', 'b'])
df['b'] = df['b'] + np.arange(1000)

# %%
df.tail()
# Out:
#             a           b
# 995  0.734037  995.444577
# 996  0.903070  996.009953
# 997  0.551764  997.529785
# 998  0.930767  998.999365
# 999  0.418829  999.262760

# %%
df.plot.hexbin(x='a', y='b', gridsize=10)
# Out:
# <AxesSubplot:xlabel='a', ylabel='b'>

# %%
df['z'] = np.random.uniform(0, 3, 1000)

# %%
df['z']
# Out:
# 0      1.650963
# 1      1.314882
# 2      2.863429
# 3      1.504697
# 4      0.076974
#          ...
# 995    2.460664
# 996    0.099010
# 997    2.825198
# 998    1.540666
# 999    0.991729
# Name: z, Length: 1000, dtype: float64

# %%
df.plot.hexbin(x='a', y='b', C='z', reduce_C_function=np.max, gridsize=25)
# Out:
# <AxesSubplot:xlabel='a', ylabel='b'>

# %%
series = pd.Series(3 * np.random.rand(4), index=['a', 'b', 'c', 'd'], name='series')
series
# Out:
# a    1.680991
# b    1.823578
# c    0.774050
# d    2.245327
# Name: series, dtype: float64

# %%
series.plot.pie(figsize=(6, 6))
# Out:
# <AxesSubplot:ylabel='series'>
