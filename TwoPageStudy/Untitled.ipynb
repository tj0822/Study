# %%
# 필요한 라이브러리를 불러옵니다.
import pandas as pd
import numpy as np

# %%
# 크롤링으로 가져올 url 주소를 입력합니다.
url = "http://www.seoul.go.kr/coronaV/coronaStatus.do"

# %%
table = pd.read_html(url)
len(table)
# Out:
# 6

# %%
table[0].T
# Out:
#          0    1     2     3    4
# 종로구    555    0   마포구   948   +2
# 중구     444   +3   양천구  1085   +3
# 용산구    756   +5   강서구  1651   +1
# 성동구    705   +3   구로구  1019   +9
# 광진구    735   +2   금천구   465   +3
# 동대문구  1024  +12  영등포구  1050   +7
# 중랑구   1169   +4   동작구  1158   +1
# 성북구   1227   +4   관악구  1368  +14
# 강북구    740   +4   서초구  1076   +2
# 도봉구    880   +6   강남구  1278   +2
# 노원구   1207   +4   송파구  1566   +1
# 은평구   1137   +2   강동구   920   +7
# 서대문구   758   +2    기타  3319  +17

# %%
table[1]
# Out:
#      종로구    중구   용산구   성동구   광진구  동대문구
# 0    555   444   756   705   735  1024
# 1      0    +3    +5    +3    +2   +12
# 2    중랑구   성북구   강북구   도봉구   노원구   은평구
# 3   1169  1227   740   880  1207  1137
# 4     +4    +4    +4    +6    +4    +2
# 5   서대문구   마포구   양천구   강서구   구로구   금천구
# 6    758   948  1085  1651  1019   465
# 7     +2    +2    +3    +1    +9    +3
# 8   영등포구   동작구   관악구   서초구   강남구   송파구
# 9   1050  1158  1368  1076  1278  1566
# 10    +7    +1   +14    +2    +2    +1
# 11   강동구    기타   NaN   NaN   NaN   NaN
# 12   920  3319   NaN   NaN   NaN   NaN
# 13    +7   +17   NaN   NaN   NaN   NaN

# %%
table[2].T
# Out:
#                         0
# 소계                  28240
# 해외유입                  930
# 관악구 지인·직장 관련           22
# 용산구 소재 지인모임 관련        202
# 구로구 소재 체육시설 관련         52
# 광진구 지인 모임 관련           13
# 강동구 소재 사우나 관련          30
# 양천구 가족·직장 관련           14
# 서초구 소재 의료기관(2월)관련      11
# 송파구 소재 요양병원(2월) 관련      5
# 기타 집단 감염            10104
# 기타 확진자 접촉            9058
# 타시도 확진자 접촉           1233
# 감염경로 조사중             6566

# %%
table
# Out:
# [   종로구    중구   용산구   성동구  광진구  동대문구   중랑구   성북구   강북구   도봉구   노원구   은평구  서대문구
#  0  555   444   756   705  735  1024  1169  1227   740   880  1207  1137   758
#  1    0    +3    +5    +3   +2   +12    +4    +4    +4    +6    +4    +2    +2
#  2  마포구   양천구   강서구   구로구  금천구  영등포구   동작구   관악구   서초구   강남구   송파구   강동구    기타
#  3  948  1085  1651  1019  465  1050  1158  1368  1076  1278  1566   920  3319
#  4   +2    +3    +1    +9   +3    +7    +1   +14    +2    +2    +1    +7   +17,
#       종로구    중구   용산구   성동구   광진구  동대문구
#  0    555   444   756   705   735  1024
#  1      0    +3    +5    +3    +2   +12
#  2    중랑구   성북구   강북구   도봉구   노원구   은평구
#  3   1169  1227   740   880  1207  1137
#  4     +4    +4    +4    +6    +4    +2
#  5   서대문구   마포구   양천구   강서구   구로구   금천구
#  6    758   948  1085  1651  1019   465
#  7     +2    +2    +3    +1    +9    +3
#  8   영등포구   동작구   관악구   서초구   강남구   송파구
#  9   1050  1158  1368  1076  1278  1566
#  10    +7    +1   +14    +2    +2    +1
# ...
