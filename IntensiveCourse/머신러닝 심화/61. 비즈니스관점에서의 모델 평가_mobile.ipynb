# %% [markdown]
# # 비즈니스 관점에서의 모델평가!
#
#
# * 비즈니스 관점에서 모델을 어떻게 평가할지 이해한다.
# * 모델의 결과는 기술적 평가지표가 아니라 비즈니스 성과이다.
#
# ---------------------------

# %% [markdown]
# # [1]모델링

# %% [markdown]
# ## 00.환경 준비와 데이터 로딩

# %% [markdown]
# #### 01.라이브러리 불러오기

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split

# %% [markdown]
# #### 02.데이터 업로드

# %%
# mobile data
path = "https://raw.githubusercontent.com/DA4BAM/dataset/master/mobile_cust_churn.csv"
mobile = pd.read_csv(path)

# %%
# train set과 holdout(test set) 두 df로 나눕니다.
target = 'CHURN'
x = mobile.drop(target, axis=1)
y = mobile.loc[:, target]

# %% [markdown]
# ## 20.데이터 준비

# %% [markdown]
# #### 21.변수 정리

# %%
x.drop('id', axis = 1, inplace = True)

# %% [markdown]
# #### 22.NA 처리

# %% [markdown]
# #### 23.Feature Engineering

# %% [markdown]
# #### 24.Dummy Variable

# %%
col_cat = ['REPORTED_SATISFACTION', 'REPORTED_USAGE_LEVEL', 'CONSIDERING_CHANGE_OF_PLAN' ]

# %%
# 범주형(명목형) 변수를 가변수로 만들고 붙여봅시다.

for v in col_cat :
    dummies = pd.get_dummies(x[v], prefix=v)
    x = pd.concat([x, dummies], axis=1)
    x.drop(v, axis = 1, inplace=True)

x.head()

# %% [markdown]
# #### 25.Scaling

# %% [markdown]
# #### 26.Data Split

# %%
train_x, val_x, train_y, val_y = train_test_split(x, y, test_size=0.4, random_state=1)

# %%
print(train_x.shape)
print(val_x.shape)

# %% [markdown]
# ## 30.모델링

# %% [markdown]
# ### 함수 불러오기(한꺼번에)

# %%
from sklearn.model_selection import RandomizedSearchCV, GridSearchCV
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier

from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

# %% [markdown]
# ### 모델링

# %% [markdown]
# #### 1) KNN

# %% [markdown]
# #### 2) Decision Tree

# %% [markdown]
# #### 3) Random Forest

# %% [markdown]
# #### 4) xgb

# %% [markdown]
# # [3]비즈니스 기대가치 계산
# * 회사는 현 가입 고객 1000명을 매년 유지하는게 목표입니다.
# * 이탈할 것으로 예상되는 사람에게 프로모션을 진행합니다.
#     * 최근 CRM팀에서 놀라운 프로모션을 개발하였습니다.
#     * 이 프로모션을 적용하면 고객은 절대 이탈하지 않습니다.(가상의 이야기 입니다!^^;;;)
#     * 프로모션 비용은 1인당 20만원이 듭니다.
# * 이탈하지 않을 것이라 예측을 하지만 실제로 이탈 고객은 발생할 수 있습니다.
#     * 이탈한 고객만큼 신규로 고객을 끌어들여야 합니다.
#     * 신규고객을 가입시키기 위해 들어가는 비용은 1인당 50만원입니다.
# * 1인당 비용을 가장 줄이는 예측 모델은?

# %% [markdown]
# 1) 비즈니스 가치를 매트릭스로 만드시오.

# %% [markdown]
# 2) 각 모델의 confusion matrix를 비율로 변화하시오.

# %% [markdown]
# 3) 비즈니스 기대가치로 계산하시오.
