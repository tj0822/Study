# %% [markdown]
# # 11.모델링_Review
#
# ML1 과정에서 배운 내용을 복습합니다.

# %% [markdown]
# # 실습1 : boston house price

# %% [markdown]
# ## 00.환경준비

# %% [markdown]
# ### 01.라이브러리 Import

# %%
#기본 라이브러리들을 불러오자.
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ### 02.data 불러오기

# %%
data_path = 'https://raw.githubusercontent.com/DA4BAM/dataset/master/boston.csv'
data = pd.read_csv(data_path)

# %%
data.head()

# %% [markdown]
# * 회귀인가요? 분류인가요?

# %% [markdown]
# ## 20.데이터 준비

# %% [markdown]
# 일반적인 표기
# * X : 2차원 행렬(혹은 데이터프레임), 대문자표기
# * y : 1차원 벡터, 소문자 표기
#
# 그러나 본 과정에서는 오타를 피하고자 x, y 소문자로 표기합니다.

# %%
# X와 y로 나누기
target = 'medv'
x = data.drop(target, axis = 1)
y = data.loc[:, target]

# %% [markdown]
# ### 26.Data Split

# %%
from sklearn.model_selection import train_test_split

# %% [markdown]
# ## 30.모델링
#
# 회귀? 분류?

# %% [markdown]
# ### 31.모델링과 평가를 위한 함수 불러오기

# %% [markdown]
# ### 32.모델 선언

# %% [markdown]
# ### 33.모델링(학습)

# %% [markdown]
# ### 34.예측

# %% [markdown]
# ### 35.평가

# %% [markdown]
# # 실습2 : iris

# %% [markdown]
# ## 00.환경준비

# %% [markdown]
# ### 01.라이브러리 Import

# %%
#기본 라이브러리들을 불러오자.
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ### 02.data 불러오기

# %%
path = 'https://raw.githubusercontent.com/DA4BAM/dataset/master/iris.csv'
data = pd.read_csv(path)

# %%
data.head()

# %% [markdown]
# ## 20.데이터 준비

# %%
# x와 y로 나누기
target = 'Species'
x = 
y =

# %% [markdown]
# ### 26.Data Split

# %% [markdown]
# ## 30.모델링

# %% [markdown]
# * 회귀? 분류?

# %% [markdown]
# ### 31.모델링과 평가를 위한 함수 불러오기

# %% [markdown]
# ### 32.모델 선언

# %% [markdown]
# ### 33.모델링(학습)

# %% [markdown]
# ### 34.예측

# %% [markdown]
# ### 35.평가
